# %%
from typing import Literal


def greeting(name : str) -> str | None:
    if name == '':
        return None
    return "Hello " + name

# %%
greet = greeting(" ")
print(greet)
# Out:
# Hello

# %%
from typing import Literal
gender = Literal["Male", "Female"]

name : str
age : int
salary : float
is_married : bool
sex : gender

scores: dict[ int, float]

job : scores
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 12
#       8 sex : gender
#       9
#      10 scores: dict[ int, float]
#      11
# ---> 12 job : scores
#      13
#      14
#      15
#
# NameError: name 'scores' is not defined
